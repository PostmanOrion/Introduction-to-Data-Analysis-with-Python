# %% [markdown]
# # Applied Machine Learning 2
# ## Course project
#                                                  Author: Diego Rodriguez
# ## Final Comparison
# Collect the test accuracy of all of the models from above in a 09 Results.ipynb notebook. You can use a DataFrame to store your results for instance

# %%
# Python code demonstrate creating  
import pandas as pd
 
# intialise data of lists.
data = {'model':['k-NN','decision tree','logistic','random forest','svm linear','svm rbf','1-layer nn','2-layer nn','cnn'],
        'test_accuracy':[96.0, 76.0, 96.0, 88.0, 92.0, 94.0, 88.0, 90.0, 52.0]}
 
# Create DataFrame
results = pd.DataFrame(data)

# %% [markdown]
# | model | test_accuracy |
# | -: | -: |
# | k-NN | 96.0 |
# | decision tree | 76.0 |
# | logistic | 96.0 |
# | random forest | 88.0 |
# | svm linear | 92.0 |
# | svm rbf | 94.0 |
# | 1-layer nn | 88.0 |
# | 2-layer nn | 90.0 |
# | cnn | 52.0 |

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# Plot with two components
fig, ax = plt.subplots(figsize=(18,10))
# Creating a bar plot
sns.barplot(x=results['model'], y=results['test_accuracy'])

# Add labels to your graph
plt.xlabel('Models')
plt.ylabel('Test Accuracy')
plt.title("Visualizing Test Accuracy")
#plt.legend()
plt.show()

# %% [markdown]
# Please, see comments and side notes in notebook **08 Convnets.ipynb**

# %% [markdown]
# The accuracy values of each of the models applied to this analysis show that for the classification of the images for the given database, the best models developed are the **k-NN classifier** and **Logistic regression**; followed by **support vector classification (SVM)** with linear kernel object.
